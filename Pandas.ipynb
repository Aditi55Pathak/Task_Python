# %%
import numpy as np
import pandas as pd

# %%
dict1={"name":["Aditi","Avani","Ishita","Pranjal"],
      "marks":[99,56,91,55],
      "age":[20,20,20,19]}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#       name  marks  age
# 0    Aditi     99   20
# 1    Avani     56   20
# 2   Ishita     91   20
# 3  Pranjal     55   19

# %%
df.to_csv('marks.csv')

# %%
df.to_csv('my_marks.csv', index=False)

# %%
df.head(2)
# Out:
#     name  marks  age
# 0  Aditi     99   20
# 1  Avani     56   20

# %%
df.tail(2)
# Out:
#       name  marks  age
# 2   Ishita     91   20
# 3  Pranjal     55   19

# %%
df.describe()
# Out:
#            marks    age
# count   4.000000   4.00
# mean   75.250000  19.75
# std    23.041629   0.50
# min    55.000000  19.00
# 25%    55.750000  19.75
# 50%    73.500000  20.00
# 75%    93.000000  20.00
# max    99.000000  20.00

# %%
aditi=pd.read_csv('cd.csv')

# %%
aditi=pd.read_csv('cd.csv')

# %%
aditi
# Out:
#     FirstName  LastName   Birthdate                       Email  \
# 0      Tanner      West  1948-03-17      kristina68@example.net
# 1         Kim      Hale  1969-07-12   martinaguilar@example.net
# 2     Jessica    Parker  1950-12-18  jenniferchavez@example.net
# 3      Ronald   Walters  1982-09-01       anthony99@example.com
# 4       David  Phillips  1997-04-20         fbailey@example.org
# ..        ...       ...         ...                         ...
# 495  Kimberly     Banks  1952-11-27    juliamaynard@example.org
# 496     James    Thomas  1949-10-04           amy25@example.net
# 497   Mikayla      Hill  1975-12-26        ronald81@example.com
# 498      Jack    Taylor  1998-05-21        lisalara@example.com
# 499     Carol    Kramer  1952-02-04        paguirre@example.com
#
#                 PhoneNumber Churn
# 0       (430)850-5833x54065    No
# 1        327.992.7584x80896    No
# 2           +1-313-397-0247   Yes
# 3              201-526-6734    No
# ...

# %%
aditi['FirstName']
# Out:
# 0        Tanner
# 1           Kim
# 2       Jessica
# 3        Ronald
# 4         David
#          ...
# 495    Kimberly
# 496       James
# 497     Mikayla
# 498        Jack
# 499       Carol
# Name: FirstName, Length: 500, dtype: object

# %%
aditi['FirstName'][0]="Neha"

# %%
aditi
# Out:
#     FirstName  LastName   Birthdate                       Email  \
# 0        Neha      West  1948-03-17      kristina68@example.net
# 1         Kim      Hale  1969-07-12   martinaguilar@example.net
# 2     Jessica    Parker  1950-12-18  jenniferchavez@example.net
# 3      Ronald   Walters  1982-09-01       anthony99@example.com
# 4       David  Phillips  1997-04-20         fbailey@example.org
# ..        ...       ...         ...                         ...
# 495  Kimberly     Banks  1952-11-27    juliamaynard@example.org
# 496     James    Thomas  1949-10-04           amy25@example.net
# 497   Mikayla      Hill  1975-12-26        ronald81@example.com
# 498      Jack    Taylor  1998-05-21        lisalara@example.com
# 499     Carol    Kramer  1952-02-04        paguirre@example.com
#
#                 PhoneNumber Churn
# 0       (430)850-5833x54065    No
# 1        327.992.7584x80896    No
# 2           +1-313-397-0247   Yes
# 3              201-526-6734    No
# ...

# %%
aditi.to_csv('cd.csv')

# %%
ser= pd.Series(numpy.random.rand(34))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 ser= pd.Series(numpy.random.rand(34))
#
# NameError: name 'numpy' is not defined

# %%
ser= pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0
# 50   0.121562  0.882732  0.244587  0.995088  0.170717  0.030583
# 73   0.163702  0.916175  0.454592  0.941299  0.907109  0.611873
# 74   0.258106  0.970170  0.008701  0.358493  0.392250  0.984571
# 92   0.027470  0.853554  0.676718  0.744608  0.529416  0.733750
# 153  0.206139  0.866173  0.618474  0.336088  0.156539  0.963048
# 174  0.193605  0.916226  0.841912  0.954460  0.946327  0.197950
# 206  0.276852  0.816648  0.790953  0.158811  0.196488  0.636176
# 210  0.178459  0.866671  0.226351  0.654177  0.861723  0.817450
# 222  0.278209  0.964294  0.351384  0.088883  0.164473  0.300376
# ...

# %%
newdf.iloc[1,4]
# Out:
# 0.3475918788168705

# %%
newdf
# Out:
#             1         2         3         4         5         6
# 0    0.040400  0.017761  0.612089  0.750996  0.859548  0.792074
# 1    0.549867  0.218813  0.687577  0.939149  0.347592  0.804444
# 2    0.845569  0.314125  0.266254  0.415728  0.748621  0.398213
# 3    0.572219  0.628490  0.607093  0.765532  0.371794  0.059298
# 4    0.074024  0.294527  0.485938  0.546530  0.968424  0.144250
# ..        ...       ...       ...       ...       ...       ...
# 329  0.766928  0.677455  0.509367  0.138953  0.417385  0.504442
# 330  0.184531  0.750341  0.095117  0.347779  0.608708  0.044991
# 331  0.260689  0.832690  0.789726  0.638275  0.379165  0.602306
# 332  0.721327  0.345785  0.859005  0.150758  0.955534  0.730058
# 333  0.180858  0.852172  0.606631  0.649451  0.430407  0.821102
#
# [334 rows x 6 columns]

# %%
newdf2
# Out:
#             0         1         2         3         4         5         6
# 0    1234.899  0.040400  0.017761  0.612089  0.750996  0.859548  0.792074
# 1    0.544439  0.549867  0.218813  0.687577  0.939149  0.347592  0.804444
# 2    0.964407  0.845569  0.314125  0.266254  0.415728  0.748621  0.398213
# 3    0.798505  0.572219  0.628490  0.607093  0.765532  0.371794  0.059298
# 4    0.073228  0.074024  0.294527  0.485938  0.546530  0.968424  0.144250
# ..        ...       ...       ...       ...       ...       ...       ...
# 329  0.144476  0.766928  0.677455  0.509367  0.138953  0.417385  0.504442
# 330  0.596233  0.184531  0.750341  0.095117  0.347779  0.608708  0.044991
# 331  0.841023  0.260689  0.832690  0.789726  0.638275  0.379165  0.602306
# 332  0.614609  0.721327  0.345785  0.859005  0.150758  0.955534  0.730058
# 333  0.893992  0.180858  0.852172  0.606631  0.649451  0.430407  0.821102
#
# [334 rows x 7 columns]

# %%
newdf.rest_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13040\2192873508.py in ?()
# ----> 1 newdf.rest_index()
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'rest_index'

# %%
newdf.head()
# Out:
#           1         2         3         4         5         6
# 0  0.040400  0.017761  0.612089  0.750996  0.859548  0.792074
# 1  0.549867  0.218813  0.687577  0.939149  0.347592  0.804444
# 2  0.845569  0.314125  0.266254  0.415728  0.748621  0.398213
# 3  0.572219  0.628490  0.607093  0.765532  0.371794  0.059298
# 4  0.074024  0.294527  0.485938  0.546530  0.968424  0.144250

# %%
newdf.reset_index()
# Out:
#      index         1         2         3         4         5         6
# 0        0  0.040400  0.017761  0.612089  0.750996  0.859548  0.792074
# 1        1  0.549867  0.218813  0.687577  0.939149  0.347592  0.804444
# 2        2  0.845569  0.314125  0.266254  0.415728  0.748621  0.398213
# 3        3  0.572219  0.628490  0.607093  0.765532  0.371794  0.059298
# 4        4  0.074024  0.294527  0.485938  0.546530  0.968424  0.144250
# ..     ...       ...       ...       ...       ...       ...       ...
# 329    329  0.766928  0.677455  0.509367  0.138953  0.417385  0.504442
# 330    330  0.184531  0.750341  0.095117  0.347779  0.608708  0.044991
# 331    331  0.260689  0.832690  0.789726  0.638275  0.379165  0.602306
# 332    332  0.721327  0.345785  0.859005  0.150758  0.955534  0.730058
# 333    333  0.180858  0.852172  0.606631  0.649451  0.430407  0.821102
#
# [334 rows x 7 columns]

# %%
newdf.reset_index()
# Out:
#      index         1         2         3         4         5         6
# 0        0  0.040400  0.017761  0.612089  0.750996  0.859548  0.792074
# 1        1  0.549867  0.218813  0.687577  0.939149  0.347592  0.804444
# 2        2  0.845569  0.314125  0.266254  0.415728  0.748621  0.398213
# 3        3  0.572219  0.628490  0.607093  0.765532  0.371794  0.059298
# 4        4  0.074024  0.294527  0.485938  0.546530  0.968424  0.144250
# ..     ...       ...       ...       ...       ...       ...       ...
# 329    329  0.766928  0.677455  0.509367  0.138953  0.417385  0.504442
# 330    330  0.184531  0.750341  0.095117  0.347779  0.608708  0.044991
# 331    331  0.260689  0.832690  0.789726  0.638275  0.379165  0.602306
# 332    332  0.721327  0.345785  0.859005  0.150758  0.955534  0.730058
# 333    333  0.180858  0.852172  0.606631  0.649451  0.430407  0.821102
#
# [334 rows x 7 columns]

# %%
newdf.reset_index(drop=True, inplace=True)

# %%
newdf
# Out:
#             1         2         3         4         5         6
# 0    0.040400  0.017761  0.612089  0.750996  0.859548  0.792074
# 1    0.549867  0.218813  0.687577  0.939149  0.347592  0.804444
# 2    0.845569  0.314125  0.266254  0.415728  0.748621  0.398213
# 3    0.572219  0.628490  0.607093  0.765532  0.371794  0.059298
# 4    0.074024  0.294527  0.485938  0.546530  0.968424  0.144250
# ..        ...       ...       ...       ...       ...       ...
# 329  0.766928  0.677455  0.509367  0.138953  0.417385  0.504442
# 330  0.184531  0.750341  0.095117  0.347779  0.608708  0.044991
# 331  0.260689  0.832690  0.789726  0.638275  0.379165  0.602306
# 332  0.721327  0.345785  0.859005  0.150758  0.955534  0.730058
# 333  0.180858  0.852172  0.606631  0.649451  0.430407  0.821102
#
# [334 rows x 6 columns]

# %%
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25, 30, 35],
        'City': ['New York', 'San Francisco', 'Los Angeles']}

# %%
data = {'Name': ['Alice', 'Bob', 'Charlie', np.nan],
        'Age': [25, 30, np.nan, 35],
        'City': ['New York', 'San Francisco', 'Los Angeles', np.nan]}

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 data.head()
#
# AttributeError: 'dict' object has no attribute 'head'

# %%
df.head()
# Out:
#       name  marks  age
# 0    Aditi     99   20
# 1    Avani     56   20
# 2   Ishita     91   20
# 3  Pranjal     55   19

# %%
data.head(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 data.head(2)
#
# AttributeError: 'dict' object has no attribute 'head'

# %%
mydf = {'Name': ['Alice', 'Bob', 'Charlie', np.nan],
        'Age': [25, 30, np.nan, 35],
        'City': ['New York', 'San Francisco', 'Los Angeles', np.nan]}

# %%
mydf
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie', nan],
#  'Age': [25, 30, nan, 35],
#  'City': ['New York', 'San Francisco', 'Los Angeles', nan]}

# %%
mydf.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 mydf.head()
#
# AttributeError: 'dict' object has no attribute 'head'

# %%
data = {'Name': ['Alice', 'Bob', 'Charlie', np.nan],
        'Age': [25, 30, np.nan, 35],
        'City': ['New York', 'San Francisco', 'Los Angeles', np.nan]}

# %%
mydf=pd.DataFrame(data)

# %%
mydf
# Out:
#       Name   Age           City
# 0    Alice  25.0       New York
# 1      Bob  30.0  San Francisco
# 2  Charlie   NaN    Los Angeles
# 3      NaN  35.0            NaN

# %%
mydf.dropna
# Out:
# <bound method DataFrame.dropna of       Name   Age           City
# 0    Alice  25.0       New York
# 1      Bob  30.0  San Francisco
# 2  Charlie   NaN    Los Angeles
# 3      NaN  35.0            NaN>

# %%
mydf.dropna(how='all')
# Out:
#       Name   Age           City
# 0    Alice  25.0       New York
# 1      Bob  30.0  San Francisco
# 2  Charlie   NaN    Los Angeles
# 3      NaN  35.0            NaN

# %%
mydf.drop_duplicates()
# Out:
#       Name   Age           City
# 0    Alice  25.0       New York
# 1      Bob  30.0  San Francisco
# 2  Charlie   NaN    Los Angeles
# 3      NaN  35.0            NaN

# %%
mydf.loc(0,"Age")=30.0
# Out:
#   Cell In[97], line 1
#     mydf.loc(0,"Age")=30.0
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
mydf.loc(0,'Age')=30.0
# Out:
#   Cell In[98], line 1
#     mydf.loc(0,'Age')=30.0
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
mydf.loc(0,'Age')==30.0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 mydf.loc(0,'Age')==30.0
#
# TypeError: _LocationIndexer.__call__() takes from 1 to 2 positional arguments but 3 were given

# %%
mydf.iloc[0]['Age'] == 30.0
# Out:
# False

# %%
mydf.loc[0, 'Age'] = 30.0

# %%
mydf
# Out:
#       Name   Age           City
# 0    Alice  30.0       New York
# 1      Bob  30.0  San Francisco
# 2  Charlie   NaN    Los Angeles
# 3      NaN  35.0            NaN

# %%
mydf.drop_duplicates(subset=['Age'],keep=False)
# Out:
#       Name   Age         City
# 2  Charlie   NaN  Los Angeles
# 3      NaN  35.0          NaN

# %%
df.shape
# Out:
# (4, 3)

# %%
df.info
# Out:
# <bound method DataFrame.info of       name  marks  age
# 0    Aditi     99   20
# 1    Avani     56   20
# 2   Ishita     91   20
# 3  Pranjal     55   19>

# %%
mydf.info
# Out:
# <bound method DataFrame.info of       Name   Age           City
# 0    Alice  30.0       New York
# 1      Bob  30.0  San Francisco
# 2  Charlie   NaN    Los Angeles
# 3      NaN  35.0            NaN>

# %%
mydf['Name'].value_counts(dropna=False)
# Out:
# Name
# Alice      1
# Bob        1
# Charlie    1
# NaN        1
# Name: count, dtype: int64

# %%
# Quick Quiz
# Create a DataFrame with integers with 3 rows and 2 columns.

# %%
myquiz=pd.DataFrame(np.random.randint(),index=np.arange(3,2)
# Out:
#   Cell In[118], line 1
#     myquiz=pd.DataFrame(np.random.randint(),index=np.arange(3,2)
#                                                                 ^
# SyntaxError: incomplete input

# %%
myquiz = pd.DataFrame(np.random.randint(1, 10, size=(3, 2)), index=np.arange(0, 3))

# %%
myquiz
# Out:
#    0  1
# 0  2  8
# 1  7  2
# 2  2  8

# %%
myquiz.mean
# Out:
# <bound method DataFrame.std of    0  1
# 0  2  8
# 1  7  2
# 2  2  8>

# %%
myquiz.corr
# Out:
# <bound method DataFrame.corr of    0  1
# 0  2  8
# 1  7  2
# 2  2  8>

# %%
myquiz.count
# Out:
# <bound method DataFrame.count of    0  1
# 0  2  8
# 1  7  2
# 2  2  8>
