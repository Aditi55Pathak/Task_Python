# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("students_data.csv")

# %%
df
# Out:
#    StudentID     Name    Citizen Group  Score
# 0        101    Akash      India     A     85
# 1        105    Rohit      India     A     78
# 2        111    Gagan      India     B     92
# 3        122     Josh    England     A     88
# 4        125  Chandan      India     B     75
# 5        130   Ramesh    England     A     91
# 6        151    Starc  Australia     B     82
# 7        158  Krishna      India     A     89
# 8        160    Jugal      India     B     76
# 9        170  Anushka  Australia     A     90

# %%
df.head(5)
# Out:
#    StudentID     Name  Citizen Group  Score
# 0        101    Akash    India     A     85
# 1        105    Rohit    India     A     78
# 2        111    Gagan    India     B     92
# 3        122     Josh  England     A     88
# 4        125  Chandan    India     B     75

# %%
df.tail(5)
# Out:
#    StudentID     Name    Citizen Group  Score
# 5        130   Ramesh    England     A     91
# 6        151    Starc  Australia     B     82
# 7        158  Krishna      India     A     89
# 8        160    Jugal      India     B     76
# 9        170  Anushka  Australia     A     90

# %%
df.to_csv("updated_data_here.csv", index=False)

# %%
df
# Out:
#    StudentID     Name    Citizen Group  Score
# 0        101    Akash      India     A     85
# 1        105    Rohit      India     A     78
# 2        111    Gagan      India     B     92
# 3        122     Josh    England     A     88
# 4        125  Chandan      India     B     75
# 5        130   Ramesh    England     A     91
# 6        151    Starc  Australia     B     82
# 7        158  Krishna      India     A     89
# 8        160    Jugal      India     B     76
# 9        170  Anushka  Australia     A     90

# %%
df.loc[(df['Group']=='A') & (df['Score']>85)]
# Out:
#    StudentID     Name    Citizen Group  Score
# 3        122     Josh    England     A     88
# 5        130   Ramesh    England     A     91
# 7        158  Krishna      India     A     89
# 9        170  Anushka  Australia     A     90

# %%
df.sort_values(by='Name', ascending=True)
# Out:
#    StudentID     Name    Citizen Group  Score
# 0        101    Akash      India     A     85
# 9        170  Anushka  Australia     A     90
# 4        125  Chandan      India     B     75
# 2        111    Gagan      India     B     92
# 3        122     Josh    England     A     88
# 8        160    Jugal      India     B     76
# 7        158  Krishna      India     A     89
# 5        130   Ramesh    England     A     91
# 1        105    Rohit      India     A     78
# 6        151    Starc  Australia     B     82

# %%
df.loc[(df['Group']=='B') & (df['Score']>50)]
# Out:
#    StudentID     Name    Citizen Group  Score
# 2        111    Gagan      India     B     92
# 4        125  Chandan      India     B     75
# 6        151    Starc  Australia     B     82
# 8        160    Jugal      India     B     76

# %%
df
# Out:
#    StudentID     Name    Citizen Group  Score
# 0        101    Akash      India     A     85
# 1        105    Rohit      India     A     78
# 2        111    Gagan      India     B     92
# 3        122     Josh    England     A     88
# 4        125  Chandan      India     B     75
# 5        130   Ramesh    England     A     91
# 6        151    Starc  Australia     B     82
# 7        158  Krishna      India     A     89
# 8        160    Jugal      India     B     76
# 9        170  Anushka  Australia     A     90

# %%
df.sort_values(by="Citizen", ascending=False)
# Out:
#    StudentID     Name    Citizen Group  Score
# 0        101    Akash      India     A     85
# 1        105    Rohit      India     A     78
# 2        111    Gagan      India     B     92
# 4        125  Chandan      India     B     75
# 7        158  Krishna      India     A     89
# 8        160    Jugal      India     B     76
# 3        122     Josh    England     A     88
# 5        130   Ramesh    England     A     91
# 6        151    Starc  Australia     B     82
# 9        170  Anushka  Australia     A     90

# %%
df=pd.read_csv("students_data.csv")

# %%
df
# Out:
#    StudentID     Name    Citizen Group  Score
# 0        101    Akash      India     A     85
# 1        105    Rohit      India     A     78
# 2        111    Gagan      India     B     92
# 3        122     Josh    England     A     88
# 4        125  Chandan      India     B     75
# 5        130   Ramesh    England     A     91
# 6        151    Starc  Australia     B     82
# 7        158  Krishna      India     A     89
# 8        160    Jugal      India     B     76
# 9        170  Anushka  Australia     A     90

# %%
df.groupby('Group')

# %%
df
# Out:
#    StudentID     Name    Citizen Group  Score
# 0        101    Akash      India     A     85
# 1        105    Rohit      India     A     78
# 2        111    Gagan      India     B     92
# 3        122     Josh    England     A     88
# 4        125  Chandan      India     B     75
# 5        130   Ramesh    England     A     91
# 6        151    Starc  Australia     B     82
# 7        158  Krishna      India     A     89
# 8        160    Jugal      India     B     76
# 9        170  Anushka  Australia     A     90

# %%
df.drop('Score', axis=1, inplace=True)

# %%
df
# Out:
#    StudentID     Name    Citizen Group
# 0        101    Akash      India     A
# 1        105    Rohit      India     A
# 2        111    Gagan      India     B
# 3        122     Josh    England     A
# 4        125  Chandan      India     B
# 5        130   Ramesh    England     A
# 6        151    Starc  Australia     B
# 7        158  Krishna      India     A
# 8        160    Jugal      India     B
# 9        170  Anushka  Australia     A
